# %%
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize
# Project Problem
x11 = LpVariable("x11", 0, None, cat = 'Integer') #Trash cans mitigation solution
x12 = LpVariable("x12", 0, None, cat = 'Integer') 
x13 = LpVariable("x13", 0, None, cat = 'Integer')
x14 = LpVariable("x14", 0, None, cat = 'Integer') 
x15 = LpVariable("x15", 0, None, cat = 'Integer') 
x16 = LpVariable("x16", 0, None, cat = 'Integer')
x17 = LpVariable("x17", 0, None, cat = 'Integer') 
x18 = LpVariable("x18", 0, None, cat = 'Integer') 
x19 = LpVariable("x19", 0, None, cat = 'Integer')
x110 = LpVariable("x110", 0, None, cat = 'Integer') 
x111 = LpVariable("x111", 0, None, cat = 'Integer') 
x112 = LpVariable("x112", 0, None, cat = 'Integer')

x21 = LpVariable("x21", 0, None, cat = 'Integer') #Rat pads mitigation solution
x22 = LpVariable("x22", 0, None, cat = 'Integer') 
x23 = LpVariable("x23", 0, None, cat = 'Integer')
x24 = LpVariable("x24", 0, None, cat = 'Integer') 
x25 = LpVariable("x25", 0, None, cat = 'Integer') 
x26 = LpVariable("x26", 0, None, cat = 'Integer')
x27 = LpVariable("x27", 0, None, cat = 'Integer') 
x28 = LpVariable("x28", 0, None, cat = 'Integer') 
x29 = LpVariable("x29", 0, None, cat = 'Integer')
x210 = LpVariable("x210", 0, None, cat = 'Integer') 
x211 = LpVariable("x211", 0, None, cat = 'Integer') 
x212 = LpVariable("x212", 0, None, cat = 'Integer')


x31 = LpVariable("x31", 0, None, cat = 'Integer') #Average service extermination mitigation solution
x32 = LpVariable("x32", 0, None, cat = 'Integer') 
x33 = LpVariable("x33", 0, None, cat = 'Integer')
x34 = LpVariable("x34", 0, None, cat = 'Integer') 
x35 = LpVariable("x35", 0, None, cat = 'Integer') 
x36 = LpVariable("x36", 0, None, cat = 'Integer')
x37 = LpVariable("x37", 0, None, cat = 'Integer') 
x38 = LpVariable("x38", 0, None, cat = 'Integer') 
x39 = LpVariable("x39", 0, None, cat = 'Integer')
x310 = LpVariable("x310", 0, None, cat = 'Integer') 
x311 = LpVariable("x311", 0, None, cat = 'Integer') 
x312 = LpVariable("x312", 0, None, cat = 'Integer')

x41 = LpVariable("x41", 0, None, cat = 'Integer') #Full service extermination mitigation solution
x42 = LpVariable("x42", 0, None, cat = 'Integer') 
x43 = LpVariable("x43", 0, None, cat = 'Integer')
x44 = LpVariable("x44", 0, None, cat = 'Integer') 
x45 = LpVariable("x45", 0, None, cat = 'Integer') 
x46 = LpVariable("x46", 0, None, cat = 'Integer')
x47 = LpVariable("x47", 0, None, cat = 'Integer') 
x48 = LpVariable("x48", 0, None, cat = 'Integer') 
x49 = LpVariable("x49", 0, None, cat = 'Integer')
x410 = LpVariable("x410", 0, None, cat = 'Integer') 
x411 = LpVariable("x411", 0, None, cat = 'Integer') 
x412 = LpVariable("x412", 0, None, cat = 'Integer')

x51 = LpVariable("x51", 0, None, cat = 'Integer') #Fumigation mitigation option
x52 = LpVariable("x52", 0, None, cat = 'Integer') 
x53 = LpVariable("x53", 0, None, cat = 'Integer')
x54 = LpVariable("x54", 0, None, cat = 'Integer') 
x55 = LpVariable("x55", 0, None, cat = 'Integer') 
x56 = LpVariable("x56", 0, None, cat = 'Integer')
x57 = LpVariable("x57", 0, None, cat = 'Integer') 
x58 = LpVariable("x58", 0, None, cat = 'Integer') 
x59 = LpVariable("x59", 0, None, cat = 'Integer')
x510 = LpVariable("x510", 0, None, cat = 'Integer') 
x511 = LpVariable("x511", 0, None, cat = 'Integer') 
x512 = LpVariable("x512", 0, None, cat = 'Integer')


# defines the problem
prob = LpProblem("problem", LpMaximize)


#constraints
#Montly Budget
prob += 7000*x11 + 3902*x21 + 520*x31 + 600*x41 +6000*x51 <= 3058666.67
prob += 7000*x12 + 3902*x22 + 520*x32 + 600*x42 +6000*x52 <= 3058666.67
prob += 7000*x13 + 3902*x23 + 520*x33 + 600*x43 +6000*x53 <= 3058666.67
prob += 7000*x14 + 3902*x24 + 520*x34 + 600*x44 +6000*x54 <= 3058666.67
prob += 7000*x15 + 3902*x25 + 520*x35 + 600*x45 +6000*x55 <= 3058666.67
prob += 7000*x16 + 3902*x26 + 520*x36 + 600*x46 +6000*x56 <= 3058666.67
prob += 7000*x17 + 3902*x27 + 520*x37 + 600*x47 +6000*x57 <= 3058666.67
prob += 7000*x18 + 3902*x28 + 520*x38 + 600*x48 +6000*x58 <= 3058666.67
prob += 7000*x19 + 3902*x29 + 520*x39 + 600*x49 +6000*x59 <= 3058666.67
prob += 7000*x110 + 3902*x210 + 520*x310 + 600*x410 +6000*x510 <= 3058666.67
prob += 7000*x111 + 3902*x211 + 520*x311 + 600*x411 +6000*x511 <= 3058666.67
prob += 7000*x112 + 3902*x212 + 520*x312 + 600*x412 +6000*x512 <= 3058666.67

#recurring costs for trash cans

prob += 20482*x11 + 18620*x12 + 16758*x13 + 14896*x14 + 13034*x15 + \
        11172*x16 + 9310*x17 + 7448*x18 + 5585*x19 +3724*x110 + 1862*x111 <= 36704000

#recurring monthly costs for average extermination treatment

prob += 5720*x31 + 5200*x32 + 4680*x33 + 4160*x34 + 640*x35 + \
        3120*x36 + 2600*x37 + 2080*x38 + 1560*x39 + 1040*x310 + 520*x311 <= 36704000

#Recurring monthly costs for full service extermingation treatment

prob += 6600*x41 + 6000*x42 + 5400*x43 + 4800*x44 + 4200*x45 \
        + 3600*x46 + 3000*x47 + 2400*x48 + 1800*x49 + 1200*x410 + 600*x411 <= 36704000

#Recurring quarterly costs for fumigation treatment

prob += 18000*x51 + 18000*x52 + 18000*x53 + 12000*x54 + \
        12000*x55 + 12000*x56 + 6000*x57 + 6000*x58 + 6000*x59  <= 36704000

#  objective function

prob += 0.7*(x11+x12+x13+x14+x15+x16+x17+x18+x19+x110+x111+x112) + \
        0.4*(x21+x22+x23+x24+x25+x26+x27+x28+x29+x210+x211+x212) + \
        0.5*(x31+x32+x33+x34+x35+x36+x37+x38+x39+x310+x311+x312) + \
        0.75*(x41+x42+x43+x44+x45+x46+x47+x48+x49+x410+x411+x412) +\
        1*(x51+x52+x53+x54+x55+x56+x57+x58+x59+x510+x511+x512)

# solve the problem
status = prob.solve()
print(f"status={LpStatus[status]}")

# print the results
for variable in prob.variables():
    print(f"{variable.name} = {variable.varValue}")
    
print(f"Objective = {value(prob.objective)}")
print(f"")
# Out:
# status=Optimal
# x11 = 0.0
# x110 = 0.0
# x111 = 0.0
# x112 = 0.0
# x12 = 0.0
# x13 = 0.0
# x14 = 0.0
# x15 = 0.0
# x16 = 0.0
# x17 = 0.0
# x18 = 0.0
# x19 = 0.0
# x21 = 1.0
# x210 = 0.0
# x211 = 0.0
# x212 = 0.0
# x22 = 1.0
# x23 = 0.0
# x24 = 0.0
# x25 = 0.0
# x26 = 0.0
# x27 = 0.0
# x28 = 0.0
# x29 = 0.0
# x31 = 1.0
# x310 = 2.0
# x311 = 2.0
# x312 = 2.0
# x32 = 1.0
# x33 = 8.0
# x34 = 1288.0
# x35 = 5882.0
# x36 = 5882.0
# x37 = 3527.0
# x38 = 2.0
# x39 = 2.0
# x41 = 0.0
# x410 = 5096.0
# x411 = 5096.0
# x412 = 5096.0
# x42 = 0.0
# x43 = 0.0
# x44 = 1.0
# x45 = 0.0
# x46 = 0.0
# x47 = 2041.0
# x48 = 5096.0
# x49 = 5096.0
# x51 = 509.0
# x510 = 0.0
# x511 = 0.0
# x512 = 0.0
# x52 = 509.0
# x53 = 509.0
# x54 = 398.0
# x55 = 0.0
# x56 = 0.0
# x57 = 0.0
# x58 = 0.0
# x59 = 0.0
# Objective = 30866.8
